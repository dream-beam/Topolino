# %%
# !pip install Harvesters
# Out:
# ...
#    ---------------------------------------- 0.0/100.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/100.3 kB ? eta -:--:--
#    ----------- --------------------------- 30.7/100.3 kB 660.6 kB/s eta 0:00:01
#    ------------------------------------ --- 92.2/100.3 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- 100.3/100.3 kB 957.6 kB/s eta 0:00:00
# ...

# %%
# !pip install genicam
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.5 MB 825.8 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.5 MB 1.3 MB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.5 MB 2.3 MB/s eta 0:00:01
#    ------------------- -------------------- 0.7/1.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.1/1.5 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 1.5/1.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 5.4 MB/s eta 0:00:00
# ...

# %%
from harvesters.core import Harvester

h = Harvester()

device_infos = h.device_info_list

for i, device_info in enumerate(device_infos):
    print(f"{i}: {device_info}")
